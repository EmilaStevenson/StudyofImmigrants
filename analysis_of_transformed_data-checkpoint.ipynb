# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
ams_df = pd.read_csv('./Data/acs_transformed.csv')

# %%
ams_df.head(12)
# Out:
#     Column1  SAMPLE  SERIAL  HHWT STATEFIP  \
# 0        58  201801      59    22  Alabama
# 1        77  201801      78    75  Alabama
# 2        89  201801      90    12  Alabama
# 3       110  201801     111    96  Alabama
# 4       148  201801     149    28  Alabama
# 5       172  201801     173    89  Alabama
# 6       263  201801     264    10  Alabama
# 7       274  201801     275   133  Alabama
# 8       290  201801     291    12  Alabama
# 9       376  201801     377    57  Alabama
# 10      411  201801     412    74  Alabama
# 11      426  201801     427    97  Alabama
#
#                                         CITY  STRATA  PERNUM  PERWT     SEX  \
# 0   Not in identifiable city (or size group)  240001       1     22  Female
# 1   Not in identifiable city (or size group)   10001       1     75  Female
# 2   Not in identifiable city (or size group)   70001       1     12    Male
# 3   Not in identifiable city (or size group)  120001       1     96    Male
# ...

# %%
ams_df.tail(12)
# Out:
#         Column1  SAMPLE   SERIAL  HHWT STATEFIP  \
# 149962  3213542  201801  1410542    40  Wyoming
# 149963  3213575  201801  1410557    46  Wyoming
# 149964  3213930  201801  1410705    96  Wyoming
# 149965  3213931  201801  1410705    96  Wyoming
# 149966  3214042  201801  1410753   163  Wyoming
# 149967  3214144  201801  1410797   313  Wyoming
# 149968  3214398  201801  1410912   161  Wyoming
# 149969  3214407  201801  1410916   136  Wyoming
# 149970  3214408  201801  1410916   136  Wyoming
# 149971  3214409  201801  1410916   136  Wyoming
# 149972  3214496  201801  1410957   118  Wyoming
# 149973  3214509  201801  1410965    49  Wyoming
#
#                                             CITY  STRATA  PERNUM  PERWT  \
# 149962  Not in identifiable city (or size group)   20056       2     65
# 149963  Not in identifiable city (or size group)   50056       2     40
# 149964  Not in identifiable city (or size group)   50056       1     96
# ...

# %%
ams_df.shape
# Out:
# (149974, 30)

# %%
ams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149974 entries, 0 to 149973
# Data columns (total 30 columns):
# Column1            149974 non-null int64
# SAMPLE             149974 non-null int64
# SERIAL             149974 non-null int64
# HHWT               149974 non-null int64
# STATEFIP           149974 non-null object
# CITY               149974 non-null object
# STRATA             149974 non-null int64
# PERNUM             149974 non-null int64
# PERWT              149974 non-null int64
# SEX                149974 non-null object
# AGE                149974 non-null int64
# BPL                149974 non-null object
# BPLD               149974 non-null int64
# BPLD_DESCR         149974 non-null object
# CITIZEN            145248 non-null object
# YRIMMIG            149974 non-null int64
# YRSUSA1            149974 non-null int64
# LANGUAGE           149974 non-null object
# SPEAKENG           149974 non-null object
# SCHOOL             149974 non-null object
# ...

# %%
ams_df.isnull().sum()
# Out:
# Column1                 0
# SAMPLE                  0
# SERIAL                  0
# HHWT                    0
# STATEFIP                0
# CITY                    0
# STRATA                  0
# PERNUM                  0
# PERWT                   0
# SEX                     0
# AGE                     0
# BPL                     0
# BPLD                    0
# BPLD_DESCR              0
# CITIZEN              4726
# YRIMMIG                 0
# YRSUSA1                 0
# LANGUAGE                0
# SPEAKENG                0
# SCHOOL                  0
# EDUCD                   0
# GRADEATT           125312
# DEGFIELD            94197
# EMPSTAT                 0
# OCC                     0
# OCC_DESCRIPTION     25623
# IND                     0
# IND_DESCRIPTION     25622
# USA_MIL                 0
# USA_VPS                 0
# dtype: int64

# %%
ams_df.YRIMMIG.value_counts()
# Out:
# 2000    13587
# 2001    10552
# 2016     9481
# 2017     9437
# 2015     9092
# 2003     8131
# 2005     8053
# 2002     7911
# 2014     7773
# 2004     7642
# 2006     7421
# 2008     7141
# 2013     6909
# 2007     6867
# 2010     6507
# 2012     6342
# 2018     5729
# 2011     5701
# 2009     5698
# Name: YRIMMIG, dtype: int64

# %%
ams_df.AGE.value_counts(ascending=True)
# Out:
# 65     914
# 64     943
# 63    1081
# 62    1082
# 61    1116
# 59    1294
# 60    1323
# 58    1394
# 57    1396
# 56    1520
# 55    1725
# 54    1900
# 53    1918
# 51    1919
# 52    2006
# 50    2335
# 49    2442
# 48    2705
# 47    2905
# 46    3025
# 23    3265
# 22    3266
# 24    3343
# 44    3376
# 20    3412
# 21    3435
# 43    3493
# 45    3502
# 19    3577
# 25    3660
# 26    3678
# 18    3783
# 42    3855
# 27    3922
# 41    3986
# 28    4245
# 39    4328
# 29    4423
# 40    4589
# 37    4616
# 31    4642
# 38    4661
# 30    4914
# 36    4927
# 32    4928
# 33    4980
# 34    5030
# 35    5195
# Name: AGE, dtype: int64

# %%
ams_df.EDUCD.value_counts(ascending=True)
# Out:
# Kindergarten                                         61
# Nursery school, preschool                            85
# Grade 1                                             206
# Grade 2                                             361
# Grade 4                                             618
# Grade 3                                             773
# Grade 5                                             887
# Grade 7                                             911
# Grade 10                                           2165
# Grade 8                                            2193
# Grade 11                                           2872
# Professional degree beyond a bachelor's degree     3263
# GED or alternative credential                      3326
# Grade 9                                            3965
# Doctoral degree                                    4077
# Grade 6                                            4459
# 12th grade, no diploma                             4664
# ...

# %%
ams_df.GRADEATT.value_counts(ascending=True)
# Out:
# Grade 5 to grade 8                    73
# Grade 9 to grade 12                 2392
# Graduate or professional school     5867
# College undergraduate              16330
# Name: GRADEATT, dtype: int64

# %%
ams_df.GRADEATT.value_counts(ascending=True)
# Out:
# Grade 5 to grade 8                    73
# Grade 9 to grade 12                 2392
# Graduate or professional school     5867
# College undergraduate              16330
# Name: GRADEATT, dtype: int64

# %%
#DEGFIELD reports the field in which the person received a Bachelor's degree, if the person holds a Bachelor's degree
ams_df.DEGFIELD.value_counts(ascending=True)
# Out:
# Nuclear, Industrial Radiology, and Biological Technologies       12
# Military Technologies                                            14
# Electrical and Mechanic Repairs and Technologies                 34
# Library Science                                                  39
# Construction Services                                            62
# Cosmetology Services and Culinary Arts                           72
# Law                                                              82
# Communication Technologies                                       85
# Transportation Sciences and Technologies                         96
# Area, Ethnic, and Civilization Studies                          145
# Environment and Natural Resources                               212
# Family and Consumer Sciences                                    233
# Philosophy and Religious Studies                                280
# Physical Fitness, Parks, Recreation, and Leisure                313
# ...

# %%
newams_df=ams_df[ams_df.BPLD  != 11000]

# %%
newams_df.shape
# Out:
# (145781, 30)

# %%
newams_df=newams_df[newams_df.BPLD  != 10500]

# %%
newams_df.shape
# Out:
# (145493, 30)

# %%
newams_df=newams_df[newams_df.BPLD  != 11500]

# %%
newams_df.shape
# Out:
# (145308, 30)

# %%
newams_df=newams_df[newams_df.BPLD  != 71047]

# %%
newams_df.shape
# Out:
# (145248, 30)

# %%
newams_df.head(12)
# Out:
#     Column1  SAMPLE  SERIAL  HHWT STATEFIP  \
# 0        58  201801      59    22  Alabama
# 1        77  201801      78    75  Alabama
# 3       110  201801     111    96  Alabama
# 4       148  201801     149    28  Alabama
# 5       172  201801     173    89  Alabama
# 6       263  201801     264    10  Alabama
# 9       376  201801     377    57  Alabama
# 10      411  201801     412    74  Alabama
# 11      426  201801     427    97  Alabama
# 12      463  201801     464    75  Alabama
# 13      484  201801     485    60  Alabama
# 14      532  201801     533    70  Alabama
#
#                                         CITY  STRATA  PERNUM  PERWT     SEX  \
# 0   Not in identifiable city (or size group)  240001       1     22  Female
# 1   Not in identifiable city (or size group)   10001       1     75  Female
# 3   Not in identifiable city (or size group)  120001       1     96    Male
# 4   Not in identifiable city (or size group)  240001       1     28    Male
# ...

# %%
newams_df.to_csv('./Data/acs_drop_usterr.csv')
